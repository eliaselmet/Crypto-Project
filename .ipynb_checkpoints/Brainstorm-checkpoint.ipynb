# %%
from poloniex import Poloniex
polo = Poloniex()
help(polo)
# Out:
# Help on Poloniex in module poloniex.poloniex object:
#
# class Poloniex(PoloniexPublic)
#  |  Client to connect to Poloniex private APIs.
#  |
#  |  Method resolution order:
#  |      Poloniex
#  |      PoloniexPublic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, apikey=None, secret=None, public_url='https://poloniex.com/public', private_url='https://poloniex.com/tradingApi', limit=6, session_class=<class 'requests.sessions.Session'>, session=None, startup_lock=None, semaphore=None, timer=None, nonce_iter=None, nonce_lock=None)
#  |      Initialize the Poloniex private client.
#  |
#  |  buy(self, currencyPair, rate, amount, fillOrKill=None, immediateOrCancel=None, postOnly=None)
#  |      Places a limit buy order in a given market. Required POST parameters
#  |      are "currencyPair", "rate", and "amount". If successful, the method
#  |      will return the order number.
# ...

# %%
from poloniex import Poloniex
polo = Poloniex()
ticker = polo.returnTicker()['BTC_ETH']
print(ticker)
# Out:
# {'id': 148, 'last': 0.03388586, 'lowestAsk': 0.03389999, 'highestBid': 0.03388586, 'percentChange': -0.01408755, 'baseVolume': 196.57171545, 'quoteVolume': 5767.85630472, 'isFrozen': 0, 'high24hr': 0.03441, 'low24hr': 0.0337}

# %%
volume = polo.return24hVolume()['BTC_BCN']
volume
# Out:
# {'BTC': 5.72704159, 'BCN': 30822175.08528479}

# %%
#TIME CONVERSION
import time
import datetime
startdate= '1/1/2019'
enddate = '21/3/2019'
print(datetime.datetime.strptime(startdate, "%d/%m/%Y").timestamp())
print(datetime.datetime.strptime(enddate, "%d/%m/%Y").timestamp())
# Out:
# 1546322400.0
# 1553144400.0

# %%
#pull HISTORICAL DATA
polo.returnChartData('BTC_BCN', 900, start=1546322400.0, end=1553144400.0)
# Out:
# [{'date': 1546322400, 'high': 1.9e-07, 'low': 1.9e-07, 'open': 1.9e-07, 'close': 1.9e-07, 'volume': 0.03914, 'quoteVolume': 206000, 'weightedAverage': 1.9e-07},
#  {'date': 1546323300, 'high': 1.9e-07, 'low': 1.9e-07, 'open': 1.9e-07, 'close': 1.9e-07, 'volume': 0.0038, 'quoteVolume': 20000, 'weightedAverage': 1.9e-07},
#  {'date': 1546324200, 'high': 1.9e-07, 'low': 1.9e-07, 'open': 1.9e-07, 'close': 1.9e-07, 'volume': 0.0001005, 'quoteVolume': 528.94738769, 'weightedAverage': 1.9e-07},
#  {'date': 1546325100, 'high': 1.9e-07, 'low': 1.9e-07, 'open': 1.9e-07, 'close': 1.9e-07, 'volume': 0, 'quoteVolume': 0, 'weightedAverage': 1.9e-07},
#  {'date': 1546326000, 'high': 1.8e-07, 'low': 1.8e-07, 'open': 1.8e-07, 'close': 1.8e-07, 'volume': 0.0006172, 'quoteVolume': 3428.91381269, 'weightedAverage': 1.8e-07},
#  {'date': 1546326900, 'high': 1.9e-07, 'low': 1.9e-07, 'open': 1.9e-07, 'close': 1.9e-07, 'volume': 0.00705681, 'quoteVolume': 37141.15789473, 'weightedAverage': 1.9e-07},
# ...

# %%
#REVERSE DATESTAMP COVERSION
import os, datetime
ts = int("1546327800")

#datetime.datetime.fromtimestamp(float(os.path.getmtime(1546383600))).strftime("%B %d, %Y")
time.strftime("%a %d %b %Y GMT", time.gmtime(1546322400))
# Out:
# 'Tue 01 Jan 2019 GMT'
