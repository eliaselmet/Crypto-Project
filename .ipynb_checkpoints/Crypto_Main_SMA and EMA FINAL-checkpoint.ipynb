# %%
from poloniex import Poloniex
polo = Poloniex()
import os, datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly_express as px
import datetime

#input date time and Symbol
now = datetime.datetime.now()
startdate = '1/11/2010'
end_date= now.strftime("%d/%m/%Y")
Symbol = 'USDT_BTC'

#Set the time period to use. time categories: 7200, 14400, and 86400(daily).
timeperiod = 86400


#set the moving averages to use. MA = Simple Moving Average and EMA = Exponential Moving Average
MA1 = 10
MA2 = 20
EMA1 = 10
EMA2 = 20
#Create MA Variables
MA1_var = 'MA'+str(MA1)
MA2_var = 'MA'+str(MA2)
EMA1_var = 'EMA'+str(EMA1)
EMA2_var = 'EMA'+str(EMA2)


#pull HISTORICAL DATA
#86400 denotes daily
import pandas as pd
Daily_data =polo.returnChartData(Symbol, timeperiod, start= datetime.datetime.strptime(startdate, "%d/%m/%Y").timestamp(), end= datetime.datetime.strptime(end_date, "%d/%m/%Y").timestamp())
Daily_data = pd.DataFrame(Daily_data)
Daily_data['True Date']= pd.to_datetime(Daily_data['date'], unit='s')
Daily_data['Year']=  Daily_data['True Date'].dt.year

#moving average columns
Daily_data[MA1_var] = Daily_data['close'].rolling(MA1).mean()
Daily_data[MA2_var] = Daily_data['close'].rolling(MA2).mean()
Daily_data[EMA1_var] = Daily_data['close'].ewm(span = EMA1).mean()
Daily_data[EMA2_var] = Daily_data['close'].ewm(span = EMA2).mean()

#Rules
#Shorter moving average crosses over longer. Buy at closing price Logic Buy = Short>Long or SELL = Short<Long
#The strategy will always be long or short.
#Use closing prices as entry points
#Profit/Loss -- For buy (10>50) profit = close on day of cross until until 10<50 Reversal.
#Profit/Loss -- For Sell this is the reverse

Daily_data.head(3)
# Out:
#     close        date   high     low        open  quoteVolume     volume  \
# 0  244.00  1424304000  244.0  225.00  225.000000     0.193117  46.276313
# 1  240.25  1424390400  245.0  240.25  240.250118     0.230429  55.894897
# 2  245.00  1424476800  245.0  245.00  245.000000     0.060091  14.722239
#
#    weightedAverage  True Date  Year  MA10  MA20       EMA10       EMA20
# 0       239.627778 2015-02-19  2015   NaN   NaN  244.000000  244.000000
# 1       242.568479 2015-02-20  2015   NaN   NaN  241.937500  242.031250
# 2       245.000000 2015-02-21  2015   NaN   NaN  243.168605  243.121357

# %%
#drop the Nan to get to the start of the moving averages
Daily_data= Daily_data.dropna()
Daily_data.head(2)
# Out:
#     close        date        high         low        open  quoteVolume  \
# 19  291.0  1425945600  291.000000  264.000064  264.000064     0.191296
# 20  276.0  1426032000  292.950111  276.000000  279.000106     0.149287
#
#        volume  weightedAverage  True Date  Year        MA10        MA20  \
# 19  54.961759       287.312659 2015-03-10  2015  265.922016  253.173511
# 20  42.511937       284.765718 2015-03-11  2015  268.422016  254.773511
#
#          EMA10       EMA20
# 19  265.362350  260.024000
# 20  267.325495  261.757421

# %%
#create the long/short column:
# We create a function to loop through each row and assess whether the current trade is either Long or Short

def buy_sell_SMA (row):
   if row[MA1_var] > row[MA2_var] :
      return 'LONG'
   if row[MA1_var] < row[MA2_var] :
      return 'SHORT'    
longshort_sma = Daily_data.apply (lambda row: buy_sell_SMA(row), axis=1)
Daily_data['Long/Short SMA'] = longshort_sma

def buy_sell_EMA (row):
   if row[EMA1_var] > row[EMA2_var] :
      return 'LONG'
   if row[EMA1_var] < row[EMA2_var] :
      return 'SHORT'    
longshort_ema = Daily_data.apply (lambda row: buy_sell_EMA(row), axis=1)
Daily_data['Long/Short EMA'] = longshort_ema
Daily_data_clean = Daily_data[['True Date','Year','close','MA10','MA20','Long/Short SMA','EMA10','EMA20','Long/Short EMA']].copy()
Daily_data_clean.head(2)
# Out:
#     True Date  Year  close        MA10        MA20 Long/Short SMA       EMA10  \
# 19 2015-03-10  2015  291.0  265.922016  253.173511           LONG  265.362350
# 20 2015-03-11  2015  276.0  268.422016  254.773511           LONG  267.325495
#
#          EMA20 Long/Short EMA
# 19  260.024000           LONG
# 20  261.757421           LONG

# %%
#Find where the column values change
#this function compares current value to previous value and if they are the same = True
#If current value does not equal then it is false.
#Therefore all the "false" tags will have an exit price for our long and a entry price for our short
Daily_data_clean['SMA entry and exit'] = Daily_data_clean['Long/Short SMA'].eq(Daily_data_clean['Long/Short SMA'].shift())
Daily_data_clean['EMA entry and exit'] = Daily_data_clean['Long/Short EMA'].eq(Daily_data_clean['Long/Short EMA'].shift())

Daily_data_clean
# Out:
#       True Date  Year        close         MA10         MA20 Long/Short SMA  \
# 19   2015-03-10  2015   291.000000   265.922016   253.173511           LONG
# 20   2015-03-11  2015   276.000000   268.422016   254.773511           LONG
# 21   2015-03-12  2015   276.000001   269.122016   256.561011           LONG
# 22   2015-03-13  2015   275.110000   269.911016   258.066511           LONG
# 23   2015-03-14  2015   275.100000   269.421016   260.071511           LONG
# 24   2015-03-15  2015   282.108000   271.931804   262.426911           LONG
# 25   2015-03-16  2015   275.000000   273.431804   264.189411           LONG
# 26   2015-03-17  2015   275.000000   274.931804   266.051911           LONG
# 27   2015-03-18  2015   262.090000   275.140801   267.231411           LONG
# 28   2015-03-19  2015   264.846315   275.225432   268.023727           LONG
# 29   2015-03-20  2015   263.560831   272.481515   269.201765           LONG
# 30   2015-03-21  2015   263.192983   271.200813   269.811415           LONG
# 31   2015-03-22  2015   267.516848   270.352498   269.737257           LONG
# 32   2015-03-23  2015   260.673511   268.908849   269.409933          SHORT
# 33   2015-03-24  2015   242.525507   265.651400   267.536208          SHORT
# 34   2015-03-25  2015   247.475515   262.188151   267.059978          SHORT
# 35   2015-03-26  2015   242.525500   258.940701   266.186253          SHORT
# 36   2015-03-27  2015   253.352700   256.775971   265.853887          SHORT
# 37   2015-03-28  2015   248.728496   255.439821   265.290311          SHORT
# 38   2015-03-29  2015   247.969330   253.752122   264.488777          SHORT
# 39   2015-03-30  2015   254.352794   252.831318   262.656417          SHORT
# 40   2015-03-31  2015   249.338530   251.445873   261.323343          SHORT
# 41   2015-04-01  2015   249.000000   249.594188   259.973343          SHORT
# 42   2015-04-02  2015   255.000000   249.026837   258.967843          SHORT
# 43   2015-04-03  2015   255.000000   250.274286   257.962843          SHORT
# 44   2015-04-04  2015   254.427177   250.969453   256.578802          SHORT
# 45   2015-04-05  2015   254.696222   252.186525   255.563613          SHORT
# 46   2015-04-06  2015   254.696222   252.320877   254.548424          SHORT
# 47   2015-04-07  2015   253.116000   252.759627   254.099724          SHORT
# 48   2015-04-08  2015   248.287031   252.791398   253.271760          SHORT
# ...         ...   ...          ...          ...          ...            ...
# 1474 2019-03-04  2019  3719.221385  3831.563934  3805.266848           LONG
# 1475 2019-03-05  2019  3859.058560  3806.258513  3817.761010          SHORT
# 1476 2019-03-06  2019  3861.942120  3817.358385  3831.300725          SHORT
# 1477 2019-03-07  2019  3877.511521  3822.411297  3844.910801          SHORT
# 1478 2019-03-08  2019  3860.210000  3827.303545  3856.910892          SHORT
# 1479 2019-03-09  2019  3940.294379  3839.710984  3870.442069          SHORT
# 1480 2019-03-10  2019  3921.107170  3849.742891  3871.380677          SHORT
# 1481 2019-03-11  2019  3874.370000  3854.465211  3869.363177          SHORT
# 1482 2019-03-12  2019  3881.304599  3860.209679  3864.891106          SHORT
# 1483 2019-03-13  2019  3866.066595  3866.108633  3861.190233           LONG
# 1484 2019-03-14  2019  3877.319333  3881.918428  3856.741181           LONG
# 1485 2019-03-15  2019  3922.888725  3888.301444  3847.279978           LONG
# 1486 2019-03-16  2019  4005.550293  3902.662262  3860.010323           LONG
# 1487 2019-03-17  2019  3986.400000  3913.551109  3867.981203           LONG
# 1488 2019-03-18  2019  3988.506298  3926.380739  3876.842142           LONG
# 1489 2019-03-19  2019  4015.610671  3933.912368  3886.811676           LONG
# 1490 2019-03-20  2019  4040.684441  3945.870096  3897.806493           LONG
# 1491 2019-03-21  2019  3982.456887  3956.678784  3905.571997           LONG
# 1492 2019-03-22  2019  3988.044099  3967.352734  3913.781206           LONG
# 1493 2019-03-23  2019  4003.800000  3981.126075  3923.617354           LONG
# 1494 2019-03-24  2019  3991.510000  3992.545141  3937.231785           LONG
# 1495 2019-03-25  2019  3943.999998  3994.656269  3941.478856           LONG
# 1496 2019-03-26  2019  3946.356301  3988.736869  3945.699566           LONG
# 1497 2019-03-27  2019  4045.470000  3994.643869  3954.097489           LONG
# 1498 2019-03-28  2019  4028.514712  3998.644711  3962.512725           LONG
# 1499 2019-03-29  2019  4104.603955  4007.544039  3970.728204           LONG
# 1500 2019-03-30  2019  4105.300000  4014.005595  3979.937845           LONG
# 1501 2019-03-31  2019  4104.759222  4026.235829  3991.457307           LONG
# 1502 2019-04-01  2019  4145.000000  4041.931419  4004.642077           LONG
# 1503 2019-04-02  2019  4861.419822  4127.693401  4054.409738           LONG
#
#             EMA10        EMA20 Long/Short EMA  SMA entry and exit  \
# 19     265.362350   260.024000           LONG               False
# 20     267.325495   261.757421           LONG                True
# 21     268.921992   263.282535           LONG                True
# 22     270.058332   264.534211           LONG                True
# 23     270.982483   265.640650           LONG                True
# 24     273.018797   267.348898           LONG                True
# 25     273.380979   268.135901           LONG                True
# 26     273.676658   268.836610           LONG                True
# 27     271.562320   268.152577           LONG                True
# 28     270.337591   267.819407           LONG                True
# 29     269.102453   267.392634           LONG                True
# 30     268.025864   266.973850           LONG                True
# 31     267.933165   267.027756           LONG                True
# 32     266.611469   266.399480           LONG               False
# 33     262.227431   264.047498          SHORT                True
# 34     259.542873   262.420217          SHORT                True
# 35     256.446549   260.472421          SHORT                True
# 36     255.883695   259.777217          SHORT                True
# 37     254.582115   258.700958          SHORT                True
# 38     253.379310   257.657852          SHORT                True
# 39     253.556365   257.337232          SHORT                True
# 40     252.789281   256.562658          SHORT                True
# 41     252.100170   255.831479          SHORT                True
# 42     252.627506   255.751205          SHORT                True
# 43     253.058932   255.678776          SHORT                True
# 44     253.307733   255.558242          SHORT                True
# 45     253.560211   255.475314          SHORT                True
# 46     253.766775   255.400436          SHORT                True
# 47     253.648444   255.181073          SHORT                True
# 48     252.673590   254.519592          SHORT                True
# ...           ...          ...            ...                 ...
# 1474  3806.982421  3783.419468           LONG                True
# 1475  3816.450810  3790.623191           LONG               False
# 1476  3824.721957  3797.415470           LONG                True
# 1477  3834.320060  3805.043665           LONG                True
# 1478  3839.027322  3810.297602           LONG                True
# 1479  3857.439514  3822.678247           LONG                True
# 1480  3869.015451  3832.052430           LONG                True
# 1481  3869.989006  3836.082675           LONG                True
# 1482  3872.046386  3840.389525           LONG                True
# 1483  3870.959152  3842.834960           LONG               False
# 1484  3872.115548  3846.119186           LONG                True
# 1485  3881.347035  3853.430571           LONG                True
# 1486  3903.929445  3867.918163           LONG                True
# 1487  3918.924092  3879.202148           LONG                True
# 1488  3931.575402  3889.612067           LONG                True
# 1489  3946.854542  3901.611934           LONG                True
# 1490  3963.914523  3914.856935           LONG                True
# 1491  3967.285862  3921.295025           LONG                True
# 1492  3971.060087  3927.652080           LONG                True
# 1493  3977.012799  3934.904263           LONG                True
# 1494  3979.648653  3940.295285           LONG                True
# 1495  3973.167080  3940.648115           LONG                True
# 1496  3968.292393  3941.191752           LONG                True
# 1497  3982.324685  3951.123014           LONG                True
# 1498  3990.722872  3958.493652           LONG                True
# 1499  4011.428523  3972.408919           LONG                True
# 1500  4028.496064  3985.065212           LONG                True
# 1501  4042.362093  3996.464642           LONG                True
# 1502  4061.023531  4010.610866           LONG                True
# 1503  4206.550129  4091.640291           LONG                True
#
#       EMA entry and exit
# 19                 False
# 20                  True
# 21                  True
# 22                  True
# 23                  True
# 24                  True
# 25                  True
# 26                  True
# 27                  True
# 28                  True
# 29                  True
# 30                  True
# 31                  True
# 32                  True
# 33                 False
# 34                  True
# 35                  True
# 36                  True
# 37                  True
# 38                  True
# 39                  True
# 40                  True
# 41                  True
# 42                  True
# 43                  True
# 44                  True
# 45                  True
# 46                  True
# 47                  True
# 48                  True
# ...                  ...
# 1474                True
# 1475                True
# 1476                True
# 1477                True
# 1478                True
# 1479                True
# 1480                True
# 1481                True
# 1482                True
# 1483                True
# 1484                True
# 1485                True
# 1486                True
# 1487                True
# 1488                True
# 1489                True
# 1490                True
# 1491                True
# 1492                True
# 1493                True
# 1494                True
# 1495                True
# 1496                True
# 1497                True
# 1498                True
# 1499                True
# 1500                True
# 1501                True
# 1502                True
# 1503                True
#
# [1485 rows x 11 columns]

# %%
#Lets pull out all the entry and exit points with closing price and Short or long column
EntryandExit_SMA = Daily_data_clean.loc[Daily_data_clean['SMA entry and exit'] == False]

#NEXT Calculate the profit/Loss per trade
#Step 1 Change all the rows named SHORT to Negative
EntryandExit_SMA.loc[EntryandExit_SMA['Long/Short SMA'] == 'LONG', 'close'] = EntryandExit_SMA['close']*-1
#Calculate the profit or loss on the trades. Fist column will be nan after that the profit or 
#loss is calculated on a per trade basis

#EntryandExit['Running Total'] = EntryandExit['Profit or Loss'].cumsum()
EntryandExit_SMA['SMA Profit/Loss'] =  EntryandExit_SMA.close+EntryandExit_SMA.close.shift(1) 
#Cumulative Profit or loss
EntryandExit_SMA['SMA Cumulative P/L'] =  EntryandExit_SMA['SMA Profit/Loss'].cumsum()

EntryandExit_SMA.head(10)
# Out:
# C:\Users\metene\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\metene\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\metene\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      True Date  Year       close        MA10        MA20 Long/Short SMA  \
# 19  2015-03-10  2015 -291.000000  265.922016  253.173511           LONG
# 32  2015-03-23  2015  260.673511  268.908849  269.409933          SHORT
# 49  2015-04-09  2015 -269.000000  254.256118  253.543718           LONG
# 53  2015-04-13  2015  246.000000  248.334015  249.304151          SHORT
# 71  2015-05-01  2015 -233.166500  228.113037  227.784595           LONG
# 95  2015-05-25  2015  234.947125  239.452078  239.546821          SHORT
# 116 2015-06-15  2015 -237.000000  233.999800  233.676780           LONG
# 155 2015-07-24  2015  284.000000  280.019968  280.049625          SHORT
# 162 2015-07-31  2015 -285.049000  286.143358  285.570552           LONG
# 170 2015-08-08  2015  263.000000  282.313877  283.834985          SHORT
#
#           EMA10       EMA20 Long/Short EMA  SMA entry and exit  \
# 19   265.362350  260.024000           LONG               False
# 32   266.611469  266.399480           LONG               False
# 49   255.642158  255.907994          SHORT               False
# 53   245.914719  249.850911          SHORT               False
# 71   229.467818  231.367927          SHORT               False
# 95   238.883787  238.520071           LONG               False
# 116  235.328568  234.794926           LONG               False
# 155  280.352460  276.659997           LONG               False
# 162  286.500376  282.721345           LONG               False
# 170  280.410443  281.434189          SHORT               False
#
#      EMA entry and exit  SMA Profit/Loss  SMA Cumulative P/L
# 19                False              NaN                 NaN
# 32                 True       -30.326489          -30.326489
# 49                 True        -8.326489          -38.652977
# 53                 True       -23.000000          -61.652977
# 71                 True        12.833500          -48.819478
# 95                 True         1.780625          -47.038853
# 116                True        -2.052875          -49.091728
# 155                True        47.000000           -2.091728
# 162                True        -1.049000           -3.140728
# 170               False       -22.049000          -25.189728

# %%
#Lets pull out all the entry and exit points with closing price and Short or long column
EntryandExit_EMA = Daily_data_clean.loc[Daily_data_clean['EMA entry and exit'] == False]

#NEXT Calculate the profit/Loss per trade
#Step 1 Change all the rows named SHORT to Negative
EntryandExit_EMA.loc[EntryandExit_EMA['Long/Short EMA'] == 'LONG', 'close'] = EntryandExit_EMA['close']*-1
#Calculate the profit or loss on the trades. Fist column will be nan after that the profit or 
#loss is calculated on a per trade basis

#EntryandExit['Running Total'] = EntryandExit['Profit or Loss'].cumsum()
EntryandExit_EMA['EMA Profit/Loss'] =  EntryandExit_EMA.close+EntryandExit_EMA.close.shift(1) 
#Cumulative Profit or loss
EntryandExit_EMA['EMA Cumulative P/L'] =  EntryandExit_EMA['EMA Profit/Loss'].cumsum()
EntryandExit_EMA.head(2)
# Out:
# C:\Users\metene\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\metene\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\metene\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     True Date  Year       close        MA10        MA20 Long/Short SMA  \
# 19 2015-03-10  2015 -291.000000  265.922016  253.173511           LONG
# 33 2015-03-24  2015  242.525507  265.651400  267.536208          SHORT
#
#          EMA10       EMA20 Long/Short EMA  SMA entry and exit  \
# 19  265.362350  260.024000           LONG               False
# 33  262.227431  264.047498          SHORT                True
#
#     EMA entry and exit  EMA Profit/Loss  EMA Cumulative P/L
# 19               False              NaN                 NaN
# 33               False       -48.474493          -48.474493

# %%
#Group by to get profit or loss per year
profit_by_year_SMA = EntryandExit_SMA[['Year','SMA Profit/Loss']]
profit_by_year_SMA = profit_by_year_SMA.groupby(['Year']).sum()
profit_by_year_SMA

profit_by_year_EMA = EntryandExit_EMA[['Year','EMA Profit/Loss']]
profit_by_year_EMA = profit_by_year_EMA.groupby(['Year']).sum()

profit_by_year = pd.concat([profit_by_year_SMA, profit_by_year_EMA],axis=1)

profit_by_year
# Out:
#       SMA Profit/Loss  EMA Profit/Loss
# Year
# 2015       102.345839         5.332147
# 2016       -97.510724       149.278737
# 2017     13929.347482      9443.886788
# 2018     -4830.165835     -7982.910353
# 2019      -531.718264      2511.586461

# %%
profit_bar = profit_by_year[['SMA Profit/Loss','EMA Profit/Loss']].plot(kind='bar', 
                                                                        title ="Annual Performace 2H", 
                                                                        figsize=(15, 10), 
                                                                        legend=True, 
                                                                        fontsize = 12)

# %%
#trade statistics
total_trades_sma= len(EntryandExit_SMA)
Total_profit_points_sma = EntryandExit_SMA['SMA Profit/Loss'].sum()
largest_drawdown_sma = EntryandExit_SMA['SMA Profit/Loss'].min()
largest_winner_sma = EntryandExit_SMA['SMA Profit/Loss'].max()

total_trades_ema= len(EntryandExit_EMA)
Total_profit_points_ema = EntryandExit_EMA['EMA Profit/Loss'].sum()
largest_drawdown_ema = EntryandExit_EMA['EMA Profit/Loss'].min()
largest_winner_ema = EntryandExit_EMA['EMA Profit/Loss'].max()

# %%
#Plot price and moving averages
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,15)) 
plt.plot(Daily_data_clean['True Date'], Daily_data_clean['close'])
plt.plot(Daily_data_clean['True Date'], Daily_data_clean[MA1_var])
plt.plot(Daily_data_clean['True Date'], Daily_data_clean[MA2_var])

# Incorporate the other graph properties
plt.title(f"{Symbol} OVER TIME 1D")
plt.ylabel("Price $")
plt.xlabel("Date")
plt.xlim('2017-01-01','2017-12-31')
plt.ylim(0
         ,12000)
plt.grid(True)


# Show plot
plt.show()

# %%
#Plot cummulative Profit /Loss
#Plot profit line
import matplotlib.pyplot as plt
plt.figure(figsize=(20,15)) 
plt.plot(EntryandExit_SMA['True Date'], EntryandExit_SMA['SMA Cumulative P/L'])

# Incorporate the other graph properties
plt.title(f"{Symbol} SMA Cumulative Profit/Loss 1D")

plt.ylabel("Cumulative Profit or Loss")
plt.xlabel("Date")
plt.grid(True)
plt.xticks(rotation = 'vertical')
plt.xlim('2017-01-01','2017-12-31')

plt.ylim(-1000,10000)


# Show plot
plt.show()

# %%
#Plot profit line
import matplotlib.pyplot as plt
plt.plot(EntryandExit['True Date'], EntryandExit['SMA Profit or Loss'])

# Incorporate the other graph properties
plt.title(f"{Symbol} Profit/Loss")
plt.ylabel("Profits")
plt.xlabel("Date")
plt.grid(True)

# Save the figure
#plt.savefig("Latitude_vs_Wind.png")

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-56e75599aa96> in <module>()
#       1 #Plot profit line
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.plot(EntryandExit['True Date'], EntryandExit['SMA Profit or Loss'])
#       4
#       5 # Incorporate the other graph properties
#
# NameError: name 'EntryandExit' is not defined

# %% [markdown]
# Start of Second Strategy: Exponential Moving average

# %%
#Plot price and moving averages
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,5)) 
plt.plot(Daily_data_EMA['True Date'], Daily_data_EMA['close'])
plt.plot(Daily_data_EMA['True Date'], Daily_data_EMA[EMA1_var])
plt.plot(Daily_data_EMA['True Date'], Daily_data_EMA[EMA2_var])

# Incorporate the other graph properties
plt.title(f"{Symbol} OVER TIME")
plt.ylabel("Price $")
plt.xlabel("Date")
plt.grid(True)

# Show plot
plt.show()

# %%
#Plot profit line
# %matplotlib inline

import matplotlib.pyplot as plt
plt.plot(EntryandExit['True Date'], EntryandExit['EMA Profit or Loss'])

# Incorporate the other graph properties
plt.title(f"{Symbol} Profit/Loss")
plt.ylabel("Profits")
plt.xlabel("Date")
plt.grid(True)
plt.figure(figsize=(30,40))

# Show plot
plt.show()

# %%
#Plot cummulative Profit /Loss
#Plot profit line
import matplotlib.pyplot as plt

plt.plot(EntryandExit['True Date'], EntryandExit['EMA Cumulative Profit or Loss'])

# Incorporate the other graph properties

plt.title(f"{Symbol} EMA Cumulative Profit/Loss")
plt.ylabel("EMA Cumulative Profit or Loss")
plt.xlabel("Date")
plt.grid(True)
plt.figure(figsize=(3,4))

plt.xticks(rotation=90)
# Save the figure

# Show plot
plt.show()

# %% [markdown]
# Comparison of Strategies -- Charts and Output

# %%
print(f"There were {total_trades_sma} trades made for the Simple Moving Average Strategy. The Total Profit/Loss from the \
strategy was ${round(Total_profit_points_sma,2)}. The largest single winner was ${round(largest_winner_sma,2)} and the largest drawdown was ${round(largest_drawdown_sma,2)}")
# Out:
# There were 75 trades made for the Simple Moving Average Strategy. The Total Profit/Loss from the strategy was $8572.3. The largest single winner was $7451.09 and the largest drawdown was $-5071.74

# %%
print(f"There were {total_trades_ema} trades made for the Exponential Moving Average Strategy. The Total Profit/Loss from the \
strategy was ${round(Total_profit_points_ema,2)}. The largest single winner was ${round(largest_winner_ema,2)} and the largest drawdown was ${round(largest_drawdown_ema,2)}")
# Out:
# There were 57 trades made for the Exponential Moving Average Strategy. The Total Profit/Loss from the strategy was $4127.17. The largest single winner was $8183.86 and the largest drawdown was $-4572.07
